# %%
from bs4 import BeautifulSoup as BS
import requests as req

url = "https://finance.naver.com/sise/sise_quant.naver"
res = req.get(url)
soup = BS(res.text, "html.parser")

print("종목 / 현재가 / 등락률")
for tr in soup.select("table.type_2 tr"):
    if len(tr.select("a.tltle")) == 0 :
        continue
    title = tr.select("a.tltle")[0].get_text(strip=True)
    price = tr.select("td.number:nth-child(3)")[0].get_text(strip=True)
    change = tr.select("td.number:nth-child(5)")[0].get_text(strip=True)
    print(title, price, change)
# Out:
# 종목 / 현재가 / 등락률
# KODEX 코스닥150선물인버스 3,450 -2.68%
# KODEX 200선물인버스2X 2,500 +1.21%
# 대창 2,115 +29.99%
# 서원 2,220 +29.98%
# 한국ANKOR유전 557 +4.70%
# 이구산업 6,170 -0.64%
# KODEX 코스닥150레버리지 14,090 +5.11%
# LS전선아시아 11,300 +7.72%
# KODEX 인버스 4,490 +0.67%
# 삼부토건 3,625 +3.57%
# 덕성 9,690 +29.89%
# 삼성전자 68,800 -1.57%
# 광명전기 2,685 -3.42%
# 에스디바이오센서 15,240 +22.21%
# KODEX 레버리지 17,075 -1.30%
# 이수페타시스 33,050 -7.68%
# 웰바이오텍 3,045 -6.31%
# 신성이엔지 2,630 -7.07%
# LS네트웍스 7,900 +5.33%
# 삼성 인버스 2X 코스닥150 선물 ETN 6,860 -5.70%
# TIGER 2차전지소재Fn 11,960 +2.18%
# 삼성중공업 8,810 -3.29%
# 일진전기 9,870 -9.12%
# 인지컨트롤스 9,450 -9.05%
# 삼성 인버스 2X WTI원유 선물 ETN 115 +4.55%
# KODEX 코스닥150 15,115 +2.75%
# 한전산업 8,580 -5.51%
# 대호에이엘 2,170 +6.37%
# 우리종금 707 -2.08%
# 미래에셋 인버스 2X 코스닥150 선물 ETN 6,865 -5.70%
# STX 15,660 +24.29%
# TIGER 코스닥150선물인버스 3,555 -2.47%
# 신한 인버스 2X WTI원유 선물 ETN(H) 105 +5.00%
# 두산에너빌리티 16,970 -4.07%
# 우리금융지주 11,570 -0.69%
# 포스코인터내셔널 82,100 -3.41%
# 고려제강 27,350 -3.36%
# 한미반도체 49,300 +0.10%
# 진원생명과학 4,670 +9.62%
# 조일알미늄 3,035 -2.25%
# 신풍제약 19,700 +4.79%
# CR홀딩스 13,500 -20.31%
# 카카오뱅크 28,350 +0.89%
# SK하이닉스 120,000 +0.42%
# KIB플러그에너지 970 -0.72%
# TIGER 차이나전기차SOLACTIVE 10,185 +0.54%
# 영풍제지 47,500 +3.26%
# HD현대인프라코어 11,100 -2.97%
# TIGER 2차전지테마 36,570 +1.70%
# ACE 미국30년국채액티브(H) 8,990 -2.60%
# 덕성우 10,840 +29.98%
# 조선내화 62,500 +5.93%
# 금양 149,000 +7.89%
# TIGER Fn반도체TOP10 9,495 -0.26%
# KODEX 미국S&P500TR 13,195 -0.71%
# 대원전선 1,182 -4.21%
# LS 114,600 -2.05%
# 바이오노트 5,970 +2.05%
# STX중공업 11,660 -7.83%
# 에이프로젠 1,482 -2.37%
# KODEX 2차전지산업 32,395 +0.72%
# 일동제약 18,410 +12.53%
# SOL 반도체소부장Fn 12,920 +1.25%
# TIGER 200선물인버스2X 2,635 +1.15%
# SK바이오사이언스 84,300 +9.06%
# KODEX 200 34,210 -0.67%
# KBSTAR 비메모리반도체액티브 10,920 +0.88%
# 카카오 53,300 +0.19%
# ACE 단기통안채 102,215 +0.04%
# LS ELECTRIC 103,000 -6.70%
# 현대로템 30,350 -3.19%
# 대원강업 6,370 -7.95%
# 일동홀딩스 13,350 +21.81%
# 대한전선 13,150 -3.73%
# POSCO홀딩스 592,000 +1.20%
# 대유플러스 932 -3.22%
# 에이프로젠바이오로직스 369 -1.07%
# 쌍용C&E 5,440 0.00%
# TIGER 미국필라델피아반도체나스닥 12,820 -2.47%
# 대우건설 4,525 -1.31%
# SOL 2차전지소부장Fn 11,165 +1.78%
# 동원금속 2,845 -4.37%
# 미래산업 30,000 -15.73%
# TRUE 인버스 2X 코스닥 150 선물 ETN 6,890 -5.62%
# KEC 1,811 -1.25%
# TIGER 탄소효율그린뉴딜 8,635 -0.17%
# KODEX 2차전지핵심소재10 Fn 12,910 +2.46%
# 동국제강 13,360 +3.97%
# 한국무브넥스 5,310 -8.29%
# 엘브이엠씨홀딩스 2,660 -0.37%
# TIGER 단기통안채 104,115 +0.02%
# DB 1,975 -1.25%
# TIGER 차이나항셍테크 6,415 +1.83%
# 서울식품 198 -0.50%
# TIGER KRX바이오K-뉴딜 6,165 +3.79%
# HMM 17,980 +0.78%
# NAVER 223,000 -1.98%
# SK증권 631 -0.32%
# 대덕전자 32,600 -2.40%
# 유한양행 73,500 +0.96%
